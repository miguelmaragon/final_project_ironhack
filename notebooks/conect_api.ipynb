# %%
import json
import pandas as pd
import requests
from pandas.io.json import json_normalize
import numpy as np
import googlemaps
from datetime import datetime
import gmaps
import gmaps.datasets
from dotenv import load_dotenv
import os
import polyline

# %%
load_dotenv()
api_key_miguel = os.environ["API_key_2"]
gmaps.configure(api_key=api_key_miguel)

# %%
gmaps_google = googlemaps.Client(key=api_key_miguel)

# Geocoding an address
geocode_result = gmaps_google.geocode('calle jacinto benavente 14, las rozas, madrid')
geocode_result2 = gmaps_google.geocode('calle fuente cisneros 10, alcorcon, madrid')

# %%
lat=str(geocode_result[0]['geometry']['location']['lat'])
lng=str(geocode_result[0]['geometry']['location']['lng'])
place_id_location = geocode_result[0]['place_id']

# %%
# url variable store url 
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location="+lat+","+lng+"&type=atm&language=es&rankby=distance&pagetoken&key="+api_key_miguel
#url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location="+lat+","+lng+"&type=atm&keyword=[cajero,atm]&language=es&rankby=distance&pagetoken&key="+API_key

# %%
# return response object 
r = requests.get(url) 

# json method of response object convert 
# json format data into python format data 
x = r.json()

# %%
data = pd.json_normalize(x['results'])

# %%
data
# Out:
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                           id  \
# 0   ebdfeab1c4a753c0972c9996f5df3bac2689617a
# 1   09fbbe7d8bfc4ef9255060eee528ee3bddb85d36
# 2   087b44db14e30a0a1ad239867ace114313fc69a8
# 3   3d5e87271c04d21723fac814752c6e1919472cff
# 4   0708f4883b0f8c4171332e0cd198ad80fddd5c94
# 5   a9cf2e32cffdd1e2f0f433ae5fe7a4a47f984b55
# 6   debaef37206ed574590317a0e07041cca6fe87af
# 7   29176e4011adabda56e7d243b1ad519920cb10fc
# 8   ac9cd61208d27cc946d059bd3c5908789e5effac
# 9   3fe93e59dfc7be0d3e369c84102d0eb22b08409c
# 10  ae5a1f7765cf2b6c11e7d69a8d50a3cb52f4d4c9
# 11  6f2d5b42eb39e30588490e8d3a7676b69c1fb005
# 12  a6106492b9d94024522c89ac0593518f7871f39a
# 13  41e65f4e4a25606882e994491455c374e5ad83b5
# 14  5da30ca6f90be8abc78f907de04fe64ac41de162
# 15  b0f801ba457ca7ab86d2a1b317277887967e1b5d
# 16  9c6815745896c9988d4c6557cbc0c4412f6221a9
# 17  93bbdf985db2ba2554fc0eff306bbdb9bd09df78
# 18  091346b07e93b29b350009cf3993683bb3a78463
# 19  9403074c7c7203e8b15cbea6ad6aea6dec4846f7
#
#                                    name  \
# 0                             Bankinter
# 1            Cajero Automático Ibercaja
# 2                                  BBVA
# 3                                Bankia
# 4                         cajero bankia
# 5                             CaixaBank
# 6   Oficina Banco Santander - Smart Red
# 7                         Santander ATM
# 8                Cajero Banco Santander
# 9                    Cajamar Caja Rural
# 10               Cajero Banco Santander
# 11    Cajero Automático Banco Santander
# 12              Oficina Banco Santander
# 13                    Cajero ING Direct
# 14             Cajero Automatico Bankia
# 15                         Cashsecurity
# 16                        Banco Popular
# 17     Euro Automatic Cash (B. Popular)
# 18              Oficina Banco Santander
# 19                        Santander ATM
#
#                                                photos  \
# 0   [{'height': 2340, 'html_attributions': ['<a hr...
# 1                                                 NaN
# 2   [{'height': 900, 'html_attributions': ['<a hre...
# 3   [{'height': 1080, 'html_attributions': ['<a hr...
# 4   [{'height': 1920, 'html_attributions': ['<a hr...
# 5   [{'height': 1080, 'html_attributions': ['<a hr...
# 6   [{'height': 2160, 'html_attributions': ['<a hr...
# 7                                                 NaN
# 8                                                 NaN
# 9   [{'height': 2160, 'html_attributions': ['<a hr...
# 10                                                NaN
# 11                                                NaN
# 12  [{'height': 500, 'html_attributions': ['<a hre...
# 13                                                NaN
# 14                                                NaN
# 15  [{'height': 4912, 'html_attributions': ['<a hr...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                        place_id  rating                    reference   scope  \
# 0   ChIJDw0KjXyDQQ0RXeQ7In3H4-k     2.0  ChIJDw0KjXyDQQ0RXeQ7In3H4-k  GOOGLE
# 1   ChIJm_qMNE6DQQ0RitUKD8PBJ7k     NaN  ChIJm_qMNE6DQQ0RitUKD8PBJ7k  GOOGLE
# 2   ChIJqZ78ayWDQQ0RqxMvi8Vokwo     1.5  ChIJqZ78ayWDQQ0RqxMvi8Vokwo  GOOGLE
# 3   ChIJjRWByjGDQQ0RSm25y4P8Rp4     3.4  ChIJjRWByjGDQQ0RSm25y4P8Rp4  GOOGLE
# 4   ChIJoWTxjy-DQQ0RikuBCYXwRjI     4.0  ChIJoWTxjy-DQQ0RikuBCYXwRjI  GOOGLE
# 5   ChIJJzsHkS-DQQ0RDt_5j-tZrK8     2.3  ChIJJzsHkS-DQQ0RDt_5j-tZrK8  GOOGLE
# 6   ChIJc_BnCSeDQQ0RLR3ICSxn5Sg     2.0  ChIJc_BnCSeDQQ0RLR3ICSxn5Sg  GOOGLE
# 7   ChIJt1ELZyWDQQ0RF8ZOit4lGJo     NaN  ChIJt1ELZyWDQQ0RF8ZOit4lGJo  GOOGLE
# 8   ChIJj6AZ9zCDQQ0RFgH7JTetY6c     3.0  ChIJj6AZ9zCDQQ0RFgH7JTetY6c  GOOGLE
# 9   ChIJfeAFJDCDQQ0RdSwm5cy4bqA     4.0  ChIJfeAFJDCDQQ0RdSwm5cy4bqA  GOOGLE
# 10  ChIJ1Q_wHy6DQQ0RdZkCaPYur9w     NaN  ChIJ1Q_wHy6DQQ0RdZkCaPYur9w  GOOGLE
# 11  ChIJ1-q3Rh-DQQ0R2GOKMwHI8so     NaN  ChIJ1-q3Rh-DQQ0R2GOKMwHI8so  GOOGLE
# 12  ChIJExXPRh-DQQ0RFZmRKu0SDjo     3.7  ChIJExXPRh-DQQ0RFZmRKu0SDjo  GOOGLE
# 13  ChIJ_WfpyxiDQQ0RuGekkWN2zlk     4.5  ChIJ_WfpyxiDQQ0RuGekkWN2zlk  GOOGLE
# 14  ChIJbSvWpTqDQQ0R82L7UMx-Ogo     NaN  ChIJbSvWpTqDQQ0R82L7UMx-Ogo  GOOGLE
# 15  ChIJZT9Pl3CDQQ0RULdDhicdQ0I     NaN  ChIJZT9Pl3CDQQ0RULdDhicdQ0I  GOOGLE
# 16  ChIJbTjJjdCCQQ0RajWktwTWxC4     NaN  ChIJbTjJjdCCQQ0RajWktwTWxC4  GOOGLE
# 17  ChIJoW3eA9GCQQ0R-cJd1bd0Rhw     NaN  ChIJoW3eA9GCQQ0R-cJd1bd0Rhw  GOOGLE
# 18  ChIJqw7cQ0CDQQ0R1ahM4TqK7JE     NaN  ChIJqw7cQ0CDQQ0R1ahM4TqK7JE  GOOGLE
# 19  ChIJUZDsvUeDQQ0R_fb_QTjIKF0     NaN  ChIJUZDsvUeDQQ0R_fb_QTjIKF0  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [bank, atm, finance, point_of_interest, establ...                 8.0
# 1    [atm, finance, point_of_interest, establishment]                 NaN
# 2   [bank, atm, finance, point_of_interest, establ...                 6.0
# 3   [bank, atm, finance, point_of_interest, establ...                 8.0
# 4    [atm, finance, point_of_interest, establishment]                 1.0
# 5   [bank, atm, finance, point_of_interest, establ...                15.0
# 6   [bank, atm, finance, point_of_interest, establ...                20.0
# 7    [atm, finance, point_of_interest, establishment]                 NaN
# 8    [atm, finance, point_of_interest, establishment]                 1.0
# 9   [bank, atm, finance, point_of_interest, establ...                 4.0
# 10   [atm, finance, point_of_interest, establishment]                 NaN
# 11   [atm, finance, point_of_interest, establishment]                 NaN
# 12  [bank, atm, finance, point_of_interest, establ...                 3.0
# 13   [atm, finance, point_of_interest, establishment]                 2.0
# 14   [atm, finance, point_of_interest, establishment]                 NaN
# 15   [atm, finance, point_of_interest, establishment]                 NaN
# 16   [atm, finance, point_of_interest, establishment]                 NaN
# 17   [atm, finance, point_of_interest, establishment]                 NaN
# 18  [bank, atm, finance, point_of_interest, establ...                 NaN
# 19   [atm, finance, point_of_interest, establishment]                 NaN
#
#                                              vicinity  geometry.location.lat  \
# 0      Calle Camilo Jose Cela, 9, Las Rozas de Madrid              40.522338
# 1     Calle Camilo Jose Cela, 16, Las Rozas de Madrid              40.522418
# 2         Av, Calle Camilo Jose Cela, 12, Monterrozas              40.520978
# 3   Parque Empresarial, Calle Severo Ochoa, 7, Las...              40.520333
# 4   (Parque Empresarial), 28230, Calle Severo Ocho...              40.520267
# 5      Calle Camilo Jose Cela, 5, Las Rozas de Madrid              40.520105
# 6     Calle Camilo Jose Cela, 10, Las Rozas de Madrid              40.519778
# 7                                               Spain              40.519776
# 8   Complejo Tripark, Calle Jacinto Benavente, 2, ...              40.520575
# 9      Calle Camilo Jose Cela, 4, Las Rozas de Madrid              40.517618
# 10  company store, Calle Juan Ramón Jiménez, Las R...              40.518266
# 11  Carretera Madrid - La Coruña, Km, 22, Las Roza...              40.524782
# 12  CARRETERA MADRID-CORUÑA, (C.C. CARREFOUR-EL PI...              40.522820
# 13  las Rozas Madrid ES, Carretera de La Coruña, P...              40.523621
# 14  Centro Comercial, Carretera de La Coruña, km. ...              40.524083
# 15  Calle Pollensa, 2, edif c Oficina 4, Las Rozas...              40.531926
# 16  CC Las Rozas 2, Avenida de Atenas, s/n, Las Ro...              40.535558
# 17        AVENIDA DE ATENAS, S/N, Las Rozas de Madrid              40.535493
# 18     Avenida de Atenas, 1, 1-3, Las Rozas de Madrid              40.535910
# 19                                              Spain              40.506978
#
#     geometry.location.lng  geometry.viewport.northeast.lat  \
# 0               -3.894599                        40.523655
# 1               -3.892928                        40.523809
# 2               -3.894358                        40.522374
# 3               -3.896713                        40.521782
# 4               -3.896659                        40.521726
# 5               -3.896884                        40.521414
# 6               -3.895586                        40.521171
# 7               -3.895556                        40.521185
# 8               -3.890291                        40.521773
# 9               -3.898014                        40.519035
# 10              -3.902508                        40.519585
# 11              -3.884866                        40.525983
# 12              -3.884677                        40.524303
# 13              -3.884369                        40.524909
# 14              -3.884210                        40.525140
# 15              -3.888925                        40.533131
# 16              -3.897969                        40.537002
# 17              -3.898584                        40.536930
# 18              -3.897570                        40.537306
# 19              -3.894417                        40.508355
#
#     geometry.viewport.northeast.lng  geometry.viewport.southwest.lat  \
# 0                         -3.893195                        40.520957
# 1                         -3.891650                        40.521111
# 2                         -3.893089                        40.519676
# 3                         -3.895262                        40.519084
# 4                         -3.895197                        40.519029
# 5                         -3.895478                        40.518716
# 6                         -3.894313                        40.518473
# 7                         -3.894145                        40.518487
# 8                         -3.889095                        40.519075
# 9                         -3.896781                        40.516337
# 10                        -3.901108                        40.516887
# 11                        -3.883613                        40.523285
# 12                        -3.883144                        40.521605
# 13                        -3.883182                        40.522212
# 14                        -3.883103                        40.522442
# 15                        -3.887602                        40.530434
# 16                        -3.896641                        40.534304
# 17                        -3.897255                        40.534232
# 18                        -3.896231                        40.534608
# 19                        -3.892999                        40.505657
#
#     geometry.viewport.southwest.lng opening_hours.open_now  \
# 0                         -3.895893                  False
# 1                         -3.894348                    NaN
# 2                         -3.895787                  False
# 3                         -3.897960                  False
# 4                         -3.897895                   True
# 5                         -3.898176                  False
# 6                         -3.897011                  False
# 7                         -3.896843                    NaN
# 8                         -3.891793                   True
# 9                         -3.899479                  False
# 10                        -3.903806                    NaN
# 11                        -3.886311                   True
# 12                        -3.885842                  False
# 13                        -3.885880                   True
# 14                        -3.885801                   True
# 15                        -3.890300                  False
# 16                        -3.899339                  False
# 17                        -3.899953                   True
# 18                        -3.898929                  False
# 19                        -3.895697                   True
#
#                 plus_code.compound_code plus_code.global_code
# 0   G4C4+W5 Las Rozas de Madrid, España           8CGRG4C4+W5
# 1   G4C4+XR Las Rozas de Madrid, España           8CGRG4C4+XR
# 2   G4C4+97 Las Rozas de Madrid, España           8CGRG4C4+97
# 3   G4C3+48 Las Rozas de Madrid, España           8CGRG4C3+48
# 4   G4C3+48 Las Rozas de Madrid, España           8CGRG4C3+48
# 5   G4C3+26 Las Rozas de Madrid, España           8CGRG4C3+26
# 6   G493+WQ Las Rozas de Madrid, España           8CGRG493+WQ
# 7   G493+WQ Las Rozas de Madrid, España           8CGRG493+WQ
# 8   G4C5+6V Las Rozas de Madrid, España           8CGRG4C5+6V
# 9   G492+2Q Las Rozas de Madrid, España           8CGRG492+2Q
# 10  G39W+8X Las Rozas de Madrid, España           8CGRG39W+8X
# 11  G4F8+W3 Las Rozas de Madrid, España           8CGRG4F8+W3
# 12  G4F8+44 Las Rozas de Madrid, España           8CGRG4F8+44
# 13  G4F8+C7 Las Rozas de Madrid, España           8CGRG4F8+C7
# 14  G4F8+J8 Las Rozas de Madrid, España           8CGRG4F8+J8
# 15  G4J6+QC Las Rozas de Madrid, España           8CGRG4J6+QC
# 16  G4P2+6R Las Rozas de Madrid, España           8CGRG4P2+6R
# 17  G4P2+5H Las Rozas de Madrid, España           8CGRG4P2+5H
# 18  G4P2+9X Las Rozas de Madrid, España           8CGRG4P2+9X
# 19  G444+Q6 Las Rozas de Madrid, España           8CGRG444+Q6

# %%
data_process = data[['name','place_id','rating','types','vicinity','geometry.location.lat','geometry.location.lng','opening_hours.open_now','icon']]

# %%
def rename_f(join):
    if 'bbva' in join:
        return 'bbva'
    elif 'santander' in join:
        return 'santander'
    elif 'kutxabank' in join:
        return 'kutxabank'
    elif 'bankia' in join:
        return 'bankia'
    elif 'unicaja' in join:
        return 'unicaja'
    elif 'ibercaja' in join:
        return 'ibercaja'
    elif 'caixabank' in join:
        return 'caixabank'
    elif 'popular' in join:
        return 'popular'
    elif 'ing direct' in join:
        return 'ing_direct'
    elif 'sabadell' in join:
        return 'sabadell'
    elif 'openbank' in join:
        return 'openbank'   
    elif 'abanka' in join:
        return 'abanka'
    elif 'liberbank' in join:
        return 'liberbank'
    elif 'deutsche' in join:
        return 'deutsche'
    elif 'bankinter' in join:
        return 'bankinter'
    else:
        return 'Otros'

# %%
data_process = data_process.copy()
data_process['name_join'] = data_process.apply(lambda row: rename_f(row['name'].lower()), axis=1)

# %%
data_process
# Out:
#                                    name                     place_id  rating  \
# 0                             Bankinter  ChIJDw0KjXyDQQ0RXeQ7In3H4-k     2.0
# 1            Cajero Automático Ibercaja  ChIJm_qMNE6DQQ0RitUKD8PBJ7k     NaN
# 2                                  BBVA  ChIJqZ78ayWDQQ0RqxMvi8Vokwo     1.5
# 3                                Bankia  ChIJjRWByjGDQQ0RSm25y4P8Rp4     3.4
# 4                         cajero bankia  ChIJoWTxjy-DQQ0RikuBCYXwRjI     4.0
# 5                             CaixaBank  ChIJJzsHkS-DQQ0RDt_5j-tZrK8     2.3
# 6   Oficina Banco Santander - Smart Red  ChIJc_BnCSeDQQ0RLR3ICSxn5Sg     2.0
# 7                         Santander ATM  ChIJt1ELZyWDQQ0RF8ZOit4lGJo     NaN
# 8                Cajero Banco Santander  ChIJj6AZ9zCDQQ0RFgH7JTetY6c     3.0
# 9                    Cajamar Caja Rural  ChIJfeAFJDCDQQ0RdSwm5cy4bqA     4.0
# 10               Cajero Banco Santander  ChIJ1Q_wHy6DQQ0RdZkCaPYur9w     NaN
# 11    Cajero Automático Banco Santander  ChIJ1-q3Rh-DQQ0R2GOKMwHI8so     NaN
# 12              Oficina Banco Santander  ChIJExXPRh-DQQ0RFZmRKu0SDjo     3.7
# 13                    Cajero ING Direct  ChIJ_WfpyxiDQQ0RuGekkWN2zlk     4.5
# 14             Cajero Automatico Bankia  ChIJbSvWpTqDQQ0R82L7UMx-Ogo     NaN
# 15                         Cashsecurity  ChIJZT9Pl3CDQQ0RULdDhicdQ0I     NaN
# 16                        Banco Popular  ChIJbTjJjdCCQQ0RajWktwTWxC4     NaN
# 17     Euro Automatic Cash (B. Popular)  ChIJoW3eA9GCQQ0R-cJd1bd0Rhw     NaN
# 18              Oficina Banco Santander  ChIJqw7cQ0CDQQ0R1ahM4TqK7JE     NaN
# 19                        Santander ATM  ChIJUZDsvUeDQQ0R_fb_QTjIKF0     NaN
#
#                                                 types  \
# 0   [bank, atm, finance, point_of_interest, establ...
# 1    [atm, finance, point_of_interest, establishment]
# 2   [bank, atm, finance, point_of_interest, establ...
# 3   [bank, atm, finance, point_of_interest, establ...
# 4    [atm, finance, point_of_interest, establishment]
# 5   [bank, atm, finance, point_of_interest, establ...
# 6   [bank, atm, finance, point_of_interest, establ...
# 7    [atm, finance, point_of_interest, establishment]
# 8    [atm, finance, point_of_interest, establishment]
# 9   [bank, atm, finance, point_of_interest, establ...
# 10   [atm, finance, point_of_interest, establishment]
# 11   [atm, finance, point_of_interest, establishment]
# 12  [bank, atm, finance, point_of_interest, establ...
# 13   [atm, finance, point_of_interest, establishment]
# 14   [atm, finance, point_of_interest, establishment]
# 15   [atm, finance, point_of_interest, establishment]
# 16   [atm, finance, point_of_interest, establishment]
# 17   [atm, finance, point_of_interest, establishment]
# 18  [bank, atm, finance, point_of_interest, establ...
# 19   [atm, finance, point_of_interest, establishment]
#
#                                              vicinity  geometry.location.lat  \
# 0      Calle Camilo Jose Cela, 9, Las Rozas de Madrid              40.522338
# 1     Calle Camilo Jose Cela, 16, Las Rozas de Madrid              40.522418
# 2         Av, Calle Camilo Jose Cela, 12, Monterrozas              40.520978
# 3   Parque Empresarial, Calle Severo Ochoa, 7, Las...              40.520333
# 4   (Parque Empresarial), 28230, Calle Severo Ocho...              40.520267
# 5      Calle Camilo Jose Cela, 5, Las Rozas de Madrid              40.520105
# 6     Calle Camilo Jose Cela, 10, Las Rozas de Madrid              40.519778
# 7                                               Spain              40.519776
# 8   Complejo Tripark, Calle Jacinto Benavente, 2, ...              40.520575
# 9      Calle Camilo Jose Cela, 4, Las Rozas de Madrid              40.517618
# 10  company store, Calle Juan Ramón Jiménez, Las R...              40.518266
# 11  Carretera Madrid - La Coruña, Km, 22, Las Roza...              40.524782
# 12  CARRETERA MADRID-CORUÑA, (C.C. CARREFOUR-EL PI...              40.522820
# 13  las Rozas Madrid ES, Carretera de La Coruña, P...              40.523621
# 14  Centro Comercial, Carretera de La Coruña, km. ...              40.524083
# 15  Calle Pollensa, 2, edif c Oficina 4, Las Rozas...              40.531926
# 16  CC Las Rozas 2, Avenida de Atenas, s/n, Las Ro...              40.535558
# 17        AVENIDA DE ATENAS, S/N, Las Rozas de Madrid              40.535493
# 18     Avenida de Atenas, 1, 1-3, Las Rozas de Madrid              40.535910
# 19                                              Spain              40.506978
#
#     geometry.location.lng opening_hours.open_now  \
# 0               -3.894599                  False
# 1               -3.892928                    NaN
# 2               -3.894358                  False
# 3               -3.896713                  False
# 4               -3.896659                   True
# 5               -3.896884                  False
# 6               -3.895586                  False
# 7               -3.895556                    NaN
# 8               -3.890291                   True
# 9               -3.898014                  False
# 10              -3.902508                    NaN
# 11              -3.884866                   True
# 12              -3.884677                  False
# 13              -3.884369                   True
# 14              -3.884210                   True
# 15              -3.888925                  False
# 16              -3.897969                  False
# 17              -3.898584                   True
# 18              -3.897570                  False
# 19              -3.894417                   True
#
#                                                  icon   name_join
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...   bankinter
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...    ibercaja
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...        bbva
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...      bankia
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...      bankia
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...   caixabank
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...   santander
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...   santander
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...   santander
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...       Otros
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...   santander
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...   santander
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...   santander
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...  ing_direct
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...      bankia
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...       Otros
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...     popular
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...     popular
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...   santander
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...   santander

# %%
comisiones = pd.read_excel("../data/raw/comisiones_bancos.xlsx")

# %%
comisiones
# Out:
#     ENTIDAD_CLIENTE ENTIDAD_CAJERO  COMISION_1  COMISION_2
# 0         caixabank      caixabank        0.00         NaN
# 1         caixabank           bbva        1.87         NaN
# 2         caixabank         bankia        1.75         NaN
# 3         caixabank       sabadell        1.80         NaN
# 4         caixabank      bankinter        1.00         NaN
# ..              ...            ...         ...         ...
# 235      liber_bank         abanca        0.50         NaN
# 236      liber_bank  deutsche_bank        2.00         NaN
# 237      liber_bank     ing_direct        0.50         NaN
# 238      liber_bank       ibercaja        0.50         NaN
# 239      liber_bank     liber_bank        0.00         NaN
#
# [240 rows x 4 columns]

# %%
result = data_process.merge(comisiones, left_on='name_join', right_on='ENTIDAD_CAJERO',how='left')

# %%
def rename_f(join):
    if 'bbva' in join:
        return 'bbva'
    elif 'santander' in join:
        return 'santander'
    elif 'kutxabank' in join:
        return 'kutxabank'
    elif 'bankia' in join:
        return 'bankia'
    elif 'unicaja' in join:
        return 'unicaja'
    elif 'ibercaja' in join:
        return 'ibercaja'
    elif 'caixabank' in join:
        return 'caixabank'
    elif 'popular' in join:
        return 'popular'
    elif 'ing direct' in join:
        return 'ing_direct'
    elif 'sabadell' in join:
        return 'sabadell'
    elif 'openbank' in join:
        return 'openbank'
    elif 'abanka' in join:
        return 'abanka'
    elif 'liberbank' in join:
        return 'liberbank'
    elif 'deutsche' in join:
        return 'deutsche'
    elif 'bankinter' in join:
        return 'bankinter'
    else:
        return 'Otros'

# %%
# card_bank = 'Santander'
card_bank = ['Santander','BBVA','caixabank']
if isinstance(card_bank, list): 
    card_bank_process = [rename_f(x.lower()) for x in card_bank]
else: 
    card_bank_process = [rename_f(card_bank.lower())]

# %%
result_client = result[(result['ENTIDAD_CLIENTE'].isin(card_bank_process))]

# %%
def upper_column(df, column):
    df = df.copy()
    df[column] = df[column].str.upper()
    return df

# %%
result_client = upper_column(result_client, 'name')
result_client = upper_column(result_client, 'ENTIDAD_CLIENTE')

# %%
result_client.head(5)
# Out:
#                           name                     place_id  rating  \
# 0                    BANKINTER  ChIJDw0KjXyDQQ0RXeQ7In3H4-k     2.0
# 1                    BANKINTER  ChIJDw0KjXyDQQ0RXeQ7In3H4-k     2.0
# 7                    BANKINTER  ChIJDw0KjXyDQQ0RXeQ7In3H4-k     2.0
# 16  CAJERO AUTOMÁTICO IBERCAJA  ChIJm_qMNE6DQQ0RitUKD8PBJ7k     NaN
# 17  CAJERO AUTOMÁTICO IBERCAJA  ChIJm_qMNE6DQQ0RitUKD8PBJ7k     NaN
#
#                                                 types  \
# 0   [bank, atm, finance, point_of_interest, establ...
# 1   [bank, atm, finance, point_of_interest, establ...
# 7   [bank, atm, finance, point_of_interest, establ...
# 16   [atm, finance, point_of_interest, establishment]
# 17   [atm, finance, point_of_interest, establishment]
#
#                                            vicinity  geometry.location.lat  \
# 0    Calle Camilo Jose Cela, 9, Las Rozas de Madrid              40.522338
# 1    Calle Camilo Jose Cela, 9, Las Rozas de Madrid              40.522338
# 7    Calle Camilo Jose Cela, 9, Las Rozas de Madrid              40.522338
# 16  Calle Camilo Jose Cela, 16, Las Rozas de Madrid              40.522418
# 17  Calle Camilo Jose Cela, 16, Las Rozas de Madrid              40.522418
#
#     geometry.location.lng opening_hours.open_now  \
# 0               -3.894599                  False
# 1               -3.894599                  False
# 7               -3.894599                  False
# 16              -3.892928                    NaN
# 17              -3.892928                    NaN
#
#                                                  icon  name_join  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...  bankinter
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...  bankinter
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...  bankinter
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...   ibercaja
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...   ibercaja
#
#    ENTIDAD_CLIENTE ENTIDAD_CAJERO  COMISION_1  COMISION_2
# 0        CAIXABANK      bankinter         1.0         NaN
# 1             BBVA      bankinter         1.0         NaN
# 7        SANTANDER      bankinter         1.0         NaN
# 16       CAIXABANK       ibercaja         1.8         NaN
# 17            BBVA       ibercaja         1.8         NaN

# %%
result_client_process = result_client[['name', 'geometry.location.lat', 'geometry.location.lng','COMISION_1','vicinity','ENTIDAD_CLIENTE','ENTIDAD_CAJERO','name_join']].drop_duplicates(subset =['ENTIDAD_CLIENTE','ENTIDAD_CAJERO'],keep='first')

# %%
result_client_process = result_client_process.loc[result_client_process.groupby("name")["COMISION_1"].idxmin()].sort_index()

# %%
result_client_process
# Out:
#                                     name  geometry.location.lat  \
# 0                              BANKINTER              40.522338
# 16            CAJERO AUTOMÁTICO IBERCAJA              40.522418
# 33                                  BBVA              40.520978
# 48                                BANKIA              40.520333
# 80                             CAIXABANK              40.520105
# 103  OFICINA BANCO SANTANDER - SMART RED              40.519778
# 193                    CAJERO ING DIRECT              40.523621
# 233                        BANCO POPULAR              40.535558
#
#      geometry.location.lng  COMISION_1  \
# 0                -3.894599        1.00
# 16               -3.892928        1.80
# 33               -3.894358        0.00
# 48               -3.896713        1.75
# 80               -3.896884        0.00
# 103              -3.895586        0.00
# 193              -3.884369        0.50
# 233              -3.897969        0.00
#
#                                               vicinity ENTIDAD_CLIENTE  \
# 0       Calle Camilo Jose Cela, 9, Las Rozas de Madrid       CAIXABANK
# 16     Calle Camilo Jose Cela, 16, Las Rozas de Madrid       CAIXABANK
# 33         Av, Calle Camilo Jose Cela, 12, Monterrozas            BBVA
# 48   Parque Empresarial, Calle Severo Ochoa, 7, Las...       CAIXABANK
# 80      Calle Camilo Jose Cela, 5, Las Rozas de Madrid       CAIXABANK
# 103    Calle Camilo Jose Cela, 10, Las Rozas de Madrid       SANTANDER
# 193  las Rozas Madrid ES, Carretera de La Coruña, P...       CAIXABANK
# 233  CC Las Rozas 2, Avenida de Atenas, s/n, Las Ro...       SANTANDER
#
#     ENTIDAD_CAJERO   name_join
# 0        bankinter   bankinter
# 16        ibercaja    ibercaja
# 33            bbva        bbva
# 48          bankia      bankia
# 80       caixabank   caixabank
# 103      santander   santander
# 193     ing_direct  ing_direct
# 233        popular     popular

# %%
atm_frees = result_client_process.loc[result_client_process.groupby("ENTIDAD_CLIENTE")["COMISION_1"].idxmin()].sort_index()

# %%
location_atm_free = (atm_frees['geometry.location.lat'].iloc[0],atm_frees['geometry.location.lng'].iloc[0])
location_atm_near = (result_client_process['geometry.location.lat'].iloc[0],result_client_process['geometry.location.lng'].iloc[0])

# %%
location_atm_free
# Out:
# (40.5209784, -3.8943583)

# %%
location_atm_near
# Out:
# (40.5223382, -3.8945987)

# %%
dict_results= result_client_process.to_dict('records')

# %%
atms_locations2 = [(rows_result['geometry.location.lat'], rows_result['geometry.location.lng']) for rows_result in dict_results]

# %%
info_box_template2 = """
<dl>
<dt>Cajero</dt><dd>{name}</dd>
<dt>Tarjeta de la entidad</dt><dd>{ENTIDAD_CLIENTE}</dd>
<dt>Comisión</dt><dd>{COMISION_1}€</dd>
<dt>Dirección</dt><dd>{vicinity}</dd>
</dl>
"""

# %%
atm_info2 = [info_box_template2.format(**atm) for atm in dict_results]

marker_layer2 = gmaps.marker_layer(atms_locations2, info_box_content=atm_info2)
fig2 = gmaps.figure()
loc2atm_free2 = gmaps.directions_layer((geocode_result[0]['geometry']['location']['lat'],geocode_result[0]['geometry']['location']['lng']),location_atm_free)
loc2atm_free2.stroke_color = 'green'
loc2atm_free2.show_markers = False
if location_atm_free != location_atm_near:
    loc2atm_near2 = gmaps.directions_layer((geocode_result[0]['geometry']['location']['lat'],geocode_result[0]['geometry']['location']['lng']),location_atm_near)
    loc2atm_near2.stroke_color = 'red'
    loc2atm_near2.show_markers = False
    fig2.add_layer(loc2atm_near2)
fig2.add_layer(loc2atm_free2)
#marker_layer2.markers.fill_color = 'blue'
fig2.add_layer(marker_layer2)
fig2
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
def plot_route(start_location,end_location,fig,color,stroke_weight_line,route_mode='driving'):
    directions_result = gmaps_google.directions(start_location,end_location,mode=route_mode)
    polyline_directions_result = polyline.decode(directions_result[0]['overview_polyline']['points'])
    
    polyline_directions_result_due = [(a,b) for a, b in zip(polyline_directions_result,polyline_directions_result[1:])]
    for i in range(len(polyline_directions_result_due)):
        line_drawing=gmaps.Line(start=polyline_directions_result_due[i][0],end=polyline_directions_result_due[i][1],stroke_weight=stroke_weight_line,stroke_color=color)
        drawing = gmaps.drawing_layer(features=[line_drawing],show_controls=False)
        fig.add_layer(drawing)

# %%
lat_home=str(geocode_result[0]['geometry']['location']['lat'])
lng_home=str(geocode_result[0]['geometry']['location']['lng'])
lat_mum=str(geocode_result2[0]['geometry']['location']['lat'])
lng_mum=str(geocode_result2[0]['geometry']['location']['lng'])

lat_home_int=geocode_result[0]['geometry']['location']['lat']
lng_home_int=geocode_result[0]['geometry']['location']['lng']

directions_to_home_driving = gmaps_google.directions((lat_home,lng_home),(lat_mum,lng_mum),mode="driving")
directions_to_home_walking = gmaps_google.directions((lat_home,lng_home),(lat_mum,lng_mum),mode="walking")

# %%
fig5 = gmaps.figure()
locations = [(lat_home_int, lng_home_int)]
marker_layer2 = gmaps.marker_layer(locations)
atm_info3 = [info_box_template2.format(**atm) for atm in dict_results]
marker_layer3 = gmaps.symbol_layer(atms_locations2, info_box_content=atm_info3,scale=6,stroke_color="yellow")
index_free = int("".join([str(integer) for integer in [i for i in range(len(atms_locations2)) if atms_locations2[i]==loc2atm_free2.end]]))
marker_layer3.markers[index_free].stroke_color = 'green'
plot_route((lat_home,lng_home),location_atm_free,fig5,'green',6.0,'walking')
if location_atm_free != location_atm_near:
    index_near = int("".join([str(integer) for integer in [i for i in range(len(atms_locations2)) if atms_locations2[i]==loc2atm_near2.end]]))
    marker_layer3.markers[index_near].stroke_color = 'red'
    plot_route((lat_home,lng_home),location_atm_near,fig5,'red',4.0,'walking')
fig5.add_layer(marker_layer2)
fig5.add_layer(marker_layer3)
fig5
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
from ipywidgets.embed import embed_minimal_html
embed_minimal_html('export.html', views=[fig5])

# %%
atm_info3 = [info_box_template2.format(**atm) for atm in dict_results]

marker_layer3 = gmaps.symbol_layer(atms_locations2, info_box_content=atm_info3,scale=6,stroke_color="blue")
fig3 = gmaps.figure()
loc2atm_free2 = gmaps.directions_layer((geocode_result[0]['geometry']['location']['lat'],geocode_result[0]['geometry']['location']['lng']),location_atm_free)
loc2atm_free2.stroke_color = 'green'
loc2atm_free2.show_markers = True
index_free = int("".join([str(integer) for integer in [i for i in range(len(atms_locations2)) if atms_locations2[i]==loc2atm_free2.end]]))
marker_layer3.markers[index_free].stroke_color = 'green'
if location_atm_free != location_atm_near:
    loc2atm_near2 = gmaps.directions_layer((geocode_result[0]['geometry']['location']['lat'],geocode_result[0]['geometry']['location']['lng']),location_atm_near,stroke_color='red',show_markers = False)
    index_near = int("".join([str(integer) for integer in [i for i in range(len(atms_locations2)) if atms_locations2[i]==loc2atm_near2.end]]))
    marker_layer3.markers[index_near].stroke_color = 'red'
fig3.add_layer(marker_layer3)
fig3.add_layer(loc2atm_near2)
fig3.add_layer(loc2atm_free2)
fig3

# %%
from ipywidgets.embed import embed_minimal_html
embed_minimal_html('export.html', views=[fig3])

# %%
from ipywidgets import IntSlider
from ipywidgets.embed import embed_minimal_html
slider = IntSlider(value=40)
embed_minimal_html('export.html', views=[fig2], title='Widgets export')

# %%
import json

from ipywidgets import IntSlider
from ipywidgets.embed import embed_data

# s1 = IntSlider(max=200, value=100)
s2 = IntSlider(value=40)
data = embed_data(views=[s2, fig3])

html_template = """
<html>
  <head>

    <title>Widget export</title>

    <!-- Load RequireJS, used by the IPywidgets for dependency management -->
    <script 
      src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" 
      integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" 
      crossorigin="anonymous">
    </script>

    <!-- Load IPywidgets bundle for embedding. -->
    <script
      data-jupyter-widgets-cdn="https://cdn.jsdelivr.net/npm/"
      src="https://unpkg.com/@jupyter-widgets/html-manager@*/dist/embed-amd.js" 
      crossorigin="anonymous">
    </script>

    <!-- The state of all the widget models on the page -->
    <script type="application/vnd.jupyter.widget-state+json">
      {manager_state}
    </script>
  </head>

  <body>

    <h1>Widget export</h1>

    <div id="first-slider-widget">
      <!-- This script tag will be replaced by the view's DOM tree -->
      <script type="application/vnd.jupyter.widget-view+json">
        {widget_views[0]}
      </script>
    </div>

    <hrule />

    <div id="second-slider-widget">
      <!-- This script tag will be replaced by the view's DOM tree -->
      <script type="application/vnd.jupyter.widget-view+json">
        {widget_views[1]}
      </script>
    </div>

  </body>
</html>
"""

manager_state = json.dumps(data['manager_state'])
widget_views = [json.dumps(view) for view in data['view_specs']]
rendered_template = html_template.format(manager_state=manager_state, widget_views=widget_views)
with open('export2.html', 'w') as fp:
    fp.write(rendered_template)
